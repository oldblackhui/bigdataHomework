# %%
import pandas as pd

# %%
df=pd.read_csv('szcat.csv',header=None)
# Out:
# D:\Anaconda3\envs\pytorch\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns=['XH','CKSJ','CX','SFZRZMC','RZSJ','BZ','SFZCKMC','CP']
df
# Out:
#             XH             CKSJ      CX   SFZRZMC              RZSJ   BZ  \
# 0          225  2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:03  深圳入
# 1          226  2020/12/22 0:07  六型车(货)     广东杏坛站   2020/12/22 0:07  深圳入
# 2          227  2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:04  深圳入
# 3          228  2020/12/22 0:07  二型车(货)  广东荷坳站机荷东  2020/12/21 23:41  深圳入
# 4          229  2020/12/22 0:07  一型车(客)   广东龙岗站水官  2020/12/21 23:47  深圳入
# ...        ...              ...     ...       ...               ...  ...
# 177930  178206              NaN  一型车(客)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177931  178207              NaN  三型车(货)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177932  178208              NaN  一型车(客)        未知  2020/12/22 23:54  深圳出
# 177933  178209              NaN  一型车(客)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177934  178210              NaN  三型车(货)   广东罗田主线站  2020/12/22 23:54  深圳出
#
#         SFZCKMC       CP
# 0       广东罗田主线站  粤A64***
# 1       广东罗田主线站  豫RW9***
# ...

# %%
df['XH'].value_counts()
# Out:
# 225       2
# 243       2
# 245       2
# 246       2
# 247       2
#          ..
# 54992     1
# 54993     1
# 54994     1
# 54995     1
# 178210    1
# Name: XH, Length: 177900, dtype: int64

# %%
df1=df.drop_duplicates(subset='XH', keep='first')

# %%
df1['XH'].value_counts()
# Out:
# 225       1
# 115183    1
# 115175    1
# 115176    1
# 115177    1
#          ..
# 54970     1
# 54971     1
# 54972     1
# 54973     1
# 178210    1
# Name: XH, Length: 177900, dtype: int64

# %%
df1
# Out:
#             XH             CKSJ      CX   SFZRZMC              RZSJ   BZ  \
# 0          225  2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:03  深圳入
# 1          226  2020/12/22 0:07  六型车(货)     广东杏坛站   2020/12/22 0:07  深圳入
# 2          227  2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:04  深圳入
# 3          228  2020/12/22 0:07  二型车(货)  广东荷坳站机荷东  2020/12/21 23:41  深圳入
# 4          229  2020/12/22 0:07  一型车(客)   广东龙岗站水官  2020/12/21 23:47  深圳入
# ...        ...              ...     ...       ...               ...  ...
# 177930  178206              NaN  一型车(客)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177931  178207              NaN  三型车(货)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177932  178208              NaN  一型车(客)        未知  2020/12/22 23:54  深圳出
# 177933  178209              NaN  一型车(客)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177934  178210              NaN  三型车(货)   广东罗田主线站  2020/12/22 23:54  深圳出
#
#         SFZCKMC       CP
# 0       广东罗田主线站  粤A64***
# 1       广东罗田主线站  豫RW9***
# ...

# %%
df1['CKSJ'].describe()
# Out:
# count               86637
# unique               1440
# top       2020/12/22 8:56
# freq                  113
# Name: CKSJ, dtype: object

# %%
df1['CKSJ'].fillna('2020/12/23 00:00',inplace=True)
# Out:
# D:\Anaconda3\envs\pytorch\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df1['CKSJ'].describe()
# Out:
# count               177900
# unique                1441
# top       2020/12/23 00:00
# freq                 91263
# Name: CKSJ, dtype: object

# %%
df1
# Out:
#             XH              CKSJ      CX   SFZRZMC              RZSJ   BZ  \
# 0          225   2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:03  深圳入
# 1          226   2020/12/22 0:07  六型车(货)     广东杏坛站   2020/12/22 0:07  深圳入
# 2          227   2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:04  深圳入
# 3          228   2020/12/22 0:07  二型车(货)  广东荷坳站机荷东  2020/12/21 23:41  深圳入
# 4          229   2020/12/22 0:07  一型车(客)   广东龙岗站水官  2020/12/21 23:47  深圳入
# ...        ...               ...     ...       ...               ...  ...
# 177930  178206  2020/12/23 00:00  一型车(客)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177931  178207  2020/12/23 00:00  三型车(货)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177932  178208  2020/12/23 00:00  一型车(客)        未知  2020/12/22 23:54  深圳出
# 177933  178209  2020/12/23 00:00  一型车(客)   广东罗田主线站  2020/12/22 23:54  深圳出
# 177934  178210  2020/12/23 00:00  三型车(货)   广东罗田主线站  2020/12/22 23:54  深圳出
#
#         SFZCKMC       CP
# 0       广东罗田主线站  粤A64***
# 1       广东罗田主线站  豫RW9***
# ...

# %%
df1['SFZCKMC'].replace('未知','未出深圳',inplace=True)
df1
# Out:
# D:\Anaconda3\envs\pytorch\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#             XH              CKSJ      CX   SFZRZMC              RZSJ   BZ  \
# 0          225   2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:03  深圳入
# 1          226   2020/12/22 0:07  六型车(货)     广东杏坛站   2020/12/22 0:07  深圳入
# 2          227   2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:04  深圳入
# 3          228   2020/12/22 0:07  二型车(货)  广东荷坳站机荷东  2020/12/21 23:41  深圳入
# 4          229   2020/12/22 0:07  一型车(客)   广东龙岗站水官  2020/12/21 23:47  深圳入
# ...        ...               ...     ...       ...               ...  ...
# 177930  178206  2020/12/23 00:00  一型车(客)   广东罗田主线站  2020/12/22 23:54  深圳出
# ...

# %%
df1['SFZRZMC'].value_counts()
# Out:
# 广东罗田主线站    69884
# 广东大岭山站     21485
# 广东水朗D站     21105
# 未知          5470
# 松山湖南        5451
#            ...
# 湖南衡东站          1
# 福建南安官桥站        1
# 河北任丘南站         1
# 福建长乐滨海站        1
# 广西陆川南站         1
# Name: SFZRZMC, Length: 1235, dtype: int64

# %%
df1['SFZRZMC'].replace('未知','广东罗田主线站',inplace=True)
df1
# Out:
# D:\Anaconda3\envs\pytorch\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#             XH              CKSJ      CX   SFZRZMC              RZSJ   BZ  \
# 0          225   2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:03  深圳入
# 1          226   2020/12/22 0:07  六型车(货)     广东杏坛站   2020/12/22 0:07  深圳入
# 2          227   2020/12/22 0:07  一型车(客)      松山湖南   2020/12/22 0:04  深圳入
# 3          228   2020/12/22 0:07  二型车(货)  广东荷坳站机荷东  2020/12/21 23:41  深圳入
# 4          229   2020/12/22 0:07  一型车(客)   广东龙岗站水官  2020/12/21 23:47  深圳入
# ...        ...               ...     ...       ...               ...  ...
# 177930  178206  2020/12/23 00:00  一型车(客)   广东罗田主线站  2020/12/22 23:54  深圳出
# ...

# %%
df1.to_csv('szcat2.csv',encoding='utf_8_sig',index=None,header=None)
